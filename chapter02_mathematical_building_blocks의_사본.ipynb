# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo212/pracAI/blob/main/chapter02_mathematical_building_blocks%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## The mathematical building blocks of neural networks

# %% [markdown]
# ### A first look at a neural network

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9254 - loss: 0.2647
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9683 - loss: 0.1101
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9793 - loss: 0.0722
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0509
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0359

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# array([2.1901387e-07, 8.6447285e-09, 8.7846793e-06, 3.5777083e-04,
#        3.0995329e-10, 5.2746236e-07, 3.0386518e-12, 9.9962282e-01,
#        2.6336047e-06, 7.2814764e-06], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# np.int64(7)

# %%
predictions[0][7]
# Out:
# np.float32(0.9996228)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9799 - loss: 0.0661
# test_acc: 0.9799000024795532

# %% [markdown]
# ### Data representations for neural networks

# %% [markdown]
# #### Scalars (rank-0 tensors)

# %%
import numpy as np
x = np.array(12)
x

# %%
x.ndim

# %% [markdown]
# #### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x

# %%
x.ndim

# %% [markdown]
# #### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim

# %% [markdown]
# #### Rank-3 tensors and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim

# %% [markdown]
# #### Key attributes

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim

# %%
train_images.shape

# %%
train_images.dtype

# %%
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]

# %% [markdown]
# #### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# #### The notion of data batches

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %% [markdown]
# #### Real-world examples of data tensors

# %% [markdown]
# ##### Vector data

# %% [markdown]
# ##### Timeseries data or sequence data

# %% [markdown]
# ##### Image data

# %% [markdown]
# ##### Video data

# %% [markdown]
# ### The gears of neural networks: Tensor operations

# %% [markdown]
# #### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.0)
print("Took: {0:.2f} s".format(time.time() - t0))

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))

# %% [markdown]
# #### Broadcasting

# %%
import numpy as np

X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.tile(y, (32, 1))

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# #### Tensor product

# %%
x = np.random.random((32,))
y = np.random.random((32,))

z = np.matmul(x, y)
z = x @ y

# %%
def naive_vector_product(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.0
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_product(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_product(x[i, :], y)
    return z

# %%
def naive_matrix_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_product(row_x, column_y)
    return z

# %% [markdown]
# #### Tensor reshaping

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
              [2., 3.],
              [4., 5.]])
x.shape

# %%
x = x.reshape((6, 1))
x

# %%
x = x.reshape((2, 3))
x

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape

# %% [markdown]
# #### Geometric interpretation of tensor operations

# %% [markdown]
# #### A geometric interpretation of deep learning

# %% [markdown]
# ### The engine of neural networks: Gradient-based optimization

# %% [markdown]
# #### What's a derivative?

# %% [markdown]
# #### Derivative of a tensor operation: The gradient

# %% [markdown]
# #### Stochastic gradient descent

# %% [markdown]
# #### Chaining derivatives: The Backpropagation algorithm

# %% [markdown]
# ##### The chain rule

# %% [markdown]
# ##### Automatic differentiation with computation graphs

# %% [markdown]
# ### Looking back at our first example

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=128,
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9254 - loss: 0.2637
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9685 - loss: 0.1077
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9797 - loss: 0.0703
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9849 - loss: 0.0512
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9888 - loss: 0.0384

# %% [markdown]
# #### Reimplementing our first example from scratch

# %% [markdown]
# ##### A simple Dense class

# %%
import keras
from keras import ops

class NaiveDense:
    def __init__(self, input_size, output_size, activation=None):
        self.activation = activation
        self.W = keras.Variable(
            shape=(input_size, output_size), initializer="uniform"
        )
        self.b = keras.Variable(shape=(output_size,), initializer="zeros")

    def __call__(self, inputs):
        x = ops.matmul(inputs, self.W)
        x = x + self.b
        if self.activation is not None:
            x = self.activation(x)
        return x

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# ##### A simple Sequential class

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
            x = layer(x)
        return x

    @property
    def weights(self):
        weights = []
        for layer in self.layers:
            weights += layer.weights
        return weights

# %%
model = NaiveSequential(
    [
        NaiveDense(input_size=28 * 28, output_size=512, activation=ops.relu),
        NaiveDense(input_size=512, output_size=10, activation=ops.softmax),
    ]
)
assert len(model.weights) == 4

# %%
model.weights
# Out:
# [<Variable path=variable, shape=(784, 512), dtype=float32, value=[[ 0.03399229 -0.02037529 -0.03100228 ... -0.02390629  0.04657799
#     0.0372757 ]
#   [ 0.017466    0.04084635  0.02159634 ...  0.00060298 -0.00538987
#    -0.01442629]
#   [ 0.01916173 -0.02456775 -0.00536777 ... -0.01105259  0.00517941
#     0.00601157]
#   ...
#   [ 0.04858439 -0.01813414  0.03814352 ... -0.04964853  0.04219736
#     0.00035645]
#   [-0.03824599 -0.02684295  0.00565764 ...  0.02011231  0.04959618
#     0.04306158]
#   [ 0.01710817 -0.00506816  0.02503271 ...  0.03427169 -0.04440885
#    -0.04637524]]>,
#  <Variable path=variable_1, shape=(512,), dtype=float32, value=[ 5.69997402e-03 -1.80923159e-03  1.11304400e-02  3.65640759e-03
#   -4.76132205e-04  9.44925658e-03  1.17693366e-02  1.30657665e-02
#    3.50288558e-03  1.18742380e-02  1.18387199e-03 -2.83449749e-03
#    1.85257022e-03  2.66030408e-03 -2.03014561e-03  2.08000792e-03
#   -5.51664853e-04  2.33594724e-03  5.09469479e-04  9.81757883e-03
#    1.69912465e-02  6.47481158e-03  7.34331494e-04  6.97149942e-03
#    9.49631352e-03  3.78038548e-03  6.15627272e-03  1.21200057e-02
#   -5.97194885e-04  1.03147915e-02 -2.74369726e-03  1.09747229e-02
#    1.36771379e-02  1.35667231e-02 -1.84674002e-03 -4.87982715e-03
#    6.94156205e-03  9.54637211e-03  4.15753433e-03  8.58536735e-03
#    9.45738330e-03  7.66627630e-03  1.45945530e-02  9.03738942e-03
#    6.94141723e-03  8.54711700e-03  6.91262074e-03  5.30713424e-03
#    2.56082579e-03  8.58367793e-03  2.87681469e-03  4.68737306e-03
#    7.06690596e-03 -8.95102858e-04 -6.51285169e-04  8.93554278e-03
#    3.78709473e-03  6.80714074e-05  3.11395130e-03  2.01382581e-03
#    1.51951360e-02 -7.16072682e-04  2.65570846e-03  1.59501769e-02
#   -7.42865785e-04  7.06337532e-03  1.05291400e-02  1.83394756e-02
#    7.58428301e-04  1.00426108e-03  5.66485198e-03  6.13278942e-03
#    7.84844998e-03  9.12969653e-03  1.77693716e-03  1.70214642e-02
#    4.52228636e-03 -3.35345347e-03  2.51896377e-03  7.54926680e-03
#    1.84888567e-03  4.45198175e-03  7.15011032e-03  2.23686490e-02
#    1.13272928e-02  1.28147639e-02  4.12242766e-03  1.76274241e-03
#    1.49483038e-02  4.10895143e-03  6.88336417e-03  1.45428698e-03
#    5.18584065e-03  1.03652710e-02 -2.88603408e-03  2.29991367e-03
#    1.92951411e-03  1.21877035e-02  4.99007059e-03 -1.87530139e-04
#    8.46581440e-03  2.68736808e-03  5.83522371e-04  4.82222950e-03
#    3.53571586e-03  9.51520354e-03  4.99810418e-03  5.33732772e-03
#   -2.04965053e-03  3.26009397e-03  9.01985075e-03  7.52208231e-04
#    5.88544505e-03  1.60836689e-02 -1.93935484e-04  8.07712728e-04
#   -1.45206426e-03 -8.13073420e-04  1.43998340e-02  6.71579444e-04
#    3.56733962e-03  5.99278742e-03  5.30845660e-04 -4.36573476e-03
#    5.47388809e-05  1.02450931e-02  3.71295353e-03 -1.59884989e-03
#    6.98729092e-03  7.46090850e-03  1.42492112e-02  5.84048824e-03
#   -2.01968220e-03 -3.21536878e-04  1.19977137e-02  1.12059331e-02
#    5.52202808e-03  1.27567421e-03  1.30923754e-02  8.00384767e-03
#    2.44338415e-03  1.09691182e-02  1.24350348e-02  1.00719333e-02
#    1.11838030e-02  2.69733556e-03  3.45321721e-03  4.69878502e-03
#    1.42287184e-02  8.45825952e-03  4.36217617e-03  2.12506228e-03
#    9.96958232e-04  2.51739705e-03  1.53626213e-04  4.38959012e-03
#   -1.52695371e-04  1.67534512e-04 -2.80897738e-03 -1.05452503e-03
#   -3.68479569e-03  5.05220098e-03  9.66363412e-04  2.89030140e-04
#    6.96731079e-03  8.35268945e-03  7.84586370e-03  9.40645346e-04
#    1.34436758e-02 -7.27675296e-03  8.98388773e-03  1.19354832e-03]>,
#  <Variable path=variable_2, shape=(512, 10), dtype=float32, value=[[-0.03943097 -0.04346516  0.02747207 ...  0.07274829 -0.01319229
#     0.07490614]
#   [-0.00231456 -0.03157128 -0.04877722 ... -0.03423068 -0.04380264
#     0.00511143]
#   [-0.02662748  0.06758425  0.01633638 ...  0.10948053  0.04799888
#    -0.00899755]
#   ...
#   [ 0.01469842  0.0062639   0.00483079 ... -0.01935161  0.02680039
#    -0.01918651]
#   [-0.04804151 -0.00955571 -0.06181574 ...  0.0012945  -0.04217275
#     0.04935322]
#   [-0.0164963   0.00415999  0.03457392 ...  0.0084323  -0.04203304
#    -0.00422316]]>,
#  <Variable path=variable_3, shape=(10,), dtype=float32, value=[-0.04130944  0.08264524 -0.02790529 -0.02244944  0.02167497  0.00638684
#   -0.00362607  0.03194292 -0.03787295 -0.00948686]>]

# %% [markdown]
# ##### A batch generator

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# #### Running one training step

# %% [markdown]
# ##### The weight update step

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign(w - g * learning_rate)

# %%
from keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ##### Gradient computation

# %%
# %%backend tensorflow
# import tensorflow as tf
#
# x = tf.zeros(shape=())
# with tf.GradientTape() as tape:
#     y = 2 * x + 3
# grad_of_y_wrt_x = tape.gradient(y, x)

# %%
# %%backend tensorflow
# def one_training_step(model, images_batch, labels_batch):
#     with tf.GradientTape() as tape:
#         predictions = model(images_batch)
#         loss = ops.sparse_categorical_crossentropy(labels_batch, predictions)
#         average_loss = ops.mean(loss)
#     gradients = tape.gradient(average_loss, model.weights)
#     update_weights(gradients, model.weights)
#     return average_loss

# %% [markdown]
# #### The full training loop

# %%
# %%backend tensorflow
# def fit(model, images, labels, epochs, batch_size=128):
#     for epoch_counter in range(epochs):
#         print(f"Epoch {epoch_counter}")
#         batch_generator = BatchGenerator(images, labels)
#         for batch_counter in range(batch_generator.num_batches):
#             images_batch, labels_batch = batch_generator.next()
#             loss = one_training_step(model, images_batch, labels_batch)
#             if batch_counter % 100 == 0:
#                 print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
# %%backend tensorflow
# from keras.datasets import mnist
#
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
#
# train_images = train_images.reshape((60000, 28 * 28))
# train_images = train_images.astype("float32") / 255
# test_images = test_images.reshape((10000, 28 * 28))
# test_images = test_images.astype("float32") / 255
#
# fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 0
# loss at batch 0: 2.33
# loss at batch 100: 2.26
# loss at batch 200: 2.25
# loss at batch 300: 2.24
# loss at batch 400: 2.17
# Epoch 1
# loss at batch 0: 2.16
# loss at batch 100: 2.12
# loss at batch 200: 2.09
# loss at batch 300: 2.08
# loss at batch 400: 2.01
# Epoch 2
# loss at batch 0: 1.99
# loss at batch 100: 1.97
# loss at batch 200: 1.92
# loss at batch 300: 1.90
# loss at batch 400: 1.84
# Epoch 3
# loss at batch 0: 1.80
# loss at batch 100: 1.81
# loss at batch 200: 1.72
# loss at batch 300: 1.72
# loss at batch 400: 1.66
# Epoch 4
# loss at batch 0: 1.61
# loss at batch 100: 1.63
# loss at batch 200: 1.53
# loss at batch 300: 1.53
# loss at batch 400: 1.49
# Epoch 5
# loss at batch 0: 1.42
# loss at batch 100: 1.46
# loss at batch 200: 1.34
# loss at batch 300: 1.35
# loss at batch 400: 1.33
# Epoch 6
# loss at batch 0: 1.25
# loss at batch 100: 1.30
# loss at batch 200: 1.17
# loss at batch 300: 1.20
# loss at batch 400: 1.19
# Epoch 7
# loss at batch 0: 1.11
# loss at batch 100: 1.16
# loss at batch 200: 1.03
# loss at batch 300: 1.07
# loss at batch 400: 1.08
# Epoch 8
# loss at batch 0: 0.99
# loss at batch 100: 1.04
# loss at batch 200: 0.91
# loss at batch 300: 0.96
# loss at batch 400: 0.99
# Epoch 9
# loss at batch 0: 0.90
# loss at batch 100: 0.95
# loss at batch 200: 0.82
# loss at batch 300: 0.88
# loss at batch 400: 0.92

# %% [markdown]
# #### Evaluating the model

# %%
# %%backend tensorflow
# predictions = model(test_images)
# predicted_labels = ops.argmax(predictions, axis=1)
# matches = predicted_labels == test_labels
# f"accuracy: {ops.mean(matches):.2f}"
